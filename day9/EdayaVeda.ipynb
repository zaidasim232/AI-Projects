# %%
import pandas as pd
# To view the Sweetviz report, you can download 'SWEETVIZ_REPORT.html' from your Colab files.
# For the D-Tale dashboard, please click on the URL provided in the previous output: http://76046104b80e:40000/dtale/main/2.
# If the D-Tale link doesn't open directly, ensure your browser isn't blocking pop-ups, or try copying and pasting the URL into a new tab.

# %%
df = pd.read_excel("cars.xls")

# %%
#pip install summarytools

# %%
from summarytools import dfSummary

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_cd013 thead>tr>th {
#   text-align: left;
# }
# #T_cd013_row0_col0, #T_cd013_row1_col0, #T_cd013_row2_col0, #T_cd013_row3_col0, #T_cd013_row4_col0, #T_cd013_row5_col0, #T_cd013_row6_col0, #T_cd013_row7_col0, #T_cd013_row8_col0, #T_cd013_row9_col0, #T_cd013_row10_col0, #T_cd013_row11_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_cd013_row0_col1, #T_cd013_row1_col1, #T_cd013_row2_col1, #T_cd013_row3_col1, #T_cd013_row4_col1, #T_cd013_row5_col1, #T_cd013_row6_col1, #T_cd013_row7_col1, #T_cd013_row8_col1, #T_cd013_row9_col1, #T_cd013_row10_col1, #T_cd013_row11_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# ...

# %%
#pip install sweetviz

# %%
import sweetviz as sv

# %%
eda = sv.analyze(df, target_feat='Price')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
eda.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
#pip install dtale

# %%
import dtale
# Out:
# /usr/local/lib/python3.12/dist-packages/kaleido/_sync_server.py:11: UserWarning:
#
#
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
#
# You can however, use the Kaleido API directly which will work with your plotly version. `kaleido.write_fig(...)`, for example. Please see the kaleido documentation.

# %%
d = dtale.show(df)
d.open_browser()

# %%
d
# Out:
# http://76046104b80e:40000/dtale/main/1

# %%
#pip install ydata-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.8/400.8 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 26.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 63.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 44.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.8 MB/s eta 0:00:00
# ...

# %%
from ydata_profiling import ProfileReport

# %%
ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.18.4&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-06-06 10:30:00.558971&quot; name=date&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
p = ProfileReport(df)

# %%
p.to_file("eda.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
