# %%
#pip install stylecloud

# %%
#pip install pillow==9.5.0

# %%
import stylecloud as sc

# %%
import matplotlib.pyplot as plt

# %%
sc.gen_stylecloud(file_path='challenge.txt', output_name='ch1.png')

# %%
from IPython.display import Image
Image(filename='ch1.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', output_name='ch2.png', icon_name='fas fa-sun')

# %%
from IPython.display import Image
Image(filename='ch2.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', output_name='ch3.png', icon_name='fas fa-cloud')

# %%
from IPython.display import Image
Image(filename='ch3.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', output_name='ch4.png', icon_name='fas fa-star-and-crescent', background_color = 'red', colors='white')

# %%
from IPython.display import Image
Image(filename='ch4.png')
