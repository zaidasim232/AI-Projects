# %% [markdown]
# # Regression : Geçmiş vrilerle geleceği tahmin etme

# %% [markdown]
# iki veya daha fazla değişken arasındaki ilişkiyi analiz için kullanılan bir yöntemdir.
# bugün regression algoritmalarını derinlemesine öğreneceğiz.
# Araba fiyatlarını tahmin eden bir makine öğrenmesi modeli geliştireceğiz. başarı oranını %85in üzerinde tutmaya çalışacaz.

# %%
pip install xlrd==2.0.1
# Out:
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
print(os.getcwd())
print(os.listdir('.'))
# Out:
# /home/zaid/Desktop/Yapay-Zeka-Kursu/day3
# ['cars.xls', 'kc_house_data.csv', 'Regression.ipynb']

# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached matplotlib-3.10.9-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (52 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached fonttools-4.63.0-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (118 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached kiwisolver-1.5.0-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached pillow-12.2.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt 


df = pd.read_excel("cars.xls")
df.head()
# Out:
#           Price  Mileage   Make    Model      Trim   Type  Cylinder  Liter  \
# 0  17314.103129     8221  Buick  Century  Sedan 4D  Sedan         6    3.1
# 1  17542.036083     9135  Buick  Century  Sedan 4D  Sedan         6    3.1
# 2  16218.847862    13196  Buick  Century  Sedan 4D  Sedan         6    3.1
# 3  16336.913140    16342  Buick  Century  Sedan 4D  Sedan         6    3.1
# 4  16339.170324    19832  Buick  Century  Sedan 4D  Sedan         6    3.1
#
#    Doors  Cruise  Sound  Leather
# 0      4       1      1        1
# 1      4       1      1        0
# 2      4       1      1        0
# 3      4       1      0        0
# 4      4       1      0        1
