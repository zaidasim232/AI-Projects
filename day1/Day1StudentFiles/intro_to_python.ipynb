# %% [markdown]
# ### Intro To Python giris

# %% [markdown]
# <font size = 3 color = green > Python Stdying </font>

# %% [markdown]
# <img width=200 src=https://devarea.com/wp-content/uploads/2017/11/python.png>

# %% [markdown]
#  $ \int_a^b \frac{dx}{sin(x)} \alpha \beta \Delta $

# %% [markdown]
# # Degisken Tanimlama Defining Variable

# %%
sayi1 = 6
sayi2 = 8
carpim = sayi1 * sayi2
print(carpim)
# Out:
# 48

# %% [markdown]
# # Veri Tipleri Data Types

# %%
a = 5
f = 2.5
str = 'Ai yapay zeka'
name = "o 'Corner"
soz = """ 'Ali'nin dayisi dedi ki "merhaba" ' """

# %%
liste = [1,3,45,565]
liste[3]
# Out:
# 565

# %%
liste2 = ['Muz', 'Elma', 'Armut']
liste2.append('Portakal')
liste2
# Out:
# ['Muz', 'Elma', 'Armut', 'Portakal']

# %%
sozluk = {'name':'Lisa','age':24,'role':'engineer'}
sozluk['name']
# Out:
# 'Lisa'

# %%
yas = int(input('Yasinizi giriniz : '))

# %%
if yas < 35:
    print('Daha gencsin')
elif yas > 35:
    print('Yaslisin')
else:
    print('Yolun yarisi')
# Out:
# Yolun yarisi

# %% [markdown]
# # Donguler

# %%
fiyat = [25,45,55,65,36]
for i in fiyat:
    print(i * 1.6)
# Out:
# 40.0
# 72.0
# 88.0
# 104.0
# 57.6

# %% [markdown]
# list Comprehention

# %%
[x * 1.6 for x in fiyat]
# Out:
# [40.0, 72.0, 88.0, 104.0, 57.6]

# %%
import pandas as pd

df = pd.read_csv('train.csv') # csv dosyalari okur
df.head() # ilk 5 satiri gosterir
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail() # son 5 satiri gosterir
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#      Gender   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df2 = df.describe()
df2.to_excel('istatistik.xlsx')

# %%
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
import seaborn as sns

sns.pairplot(df, hue = 'Survived')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df_read = pd.read_excel('istatistik.xlsx')
df_read
# Out:
#   Unnamed: 0  PassengerId    Survived      Pclass         Age       SibSp  \
# 0      count   891.000000  891.000000  891.000000  714.000000  891.000000
# 1       mean   446.000000    0.383838    2.308642   29.699118    0.523008
# 2        std   257.353842    0.486592    0.836071   14.526497    1.102743
# 3        min     1.000000    0.000000    1.000000    0.420000    0.000000
# 4        25%   223.500000    0.000000    2.000000   20.125000    0.000000
# 5        50%   446.000000    0.000000    3.000000   28.000000    0.000000
# 6        75%   668.500000    1.000000    3.000000   38.000000    1.000000
# 7        max   891.000000    1.000000    3.000000   80.000000    8.000000
#
#         Parch        Fare
# 0  891.000000  891.000000
# 1    0.381594   32.204208
# 2    0.806057   49.693429
# 3    0.000000    0.000000
# 4    0.000000    7.910400
# 5    0.000000   14.454200
# 6    0.000000   31.000000
# 7    6.000000  512.329200

# %%
import pandas as pd
import requests

url = 'https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)'
headers = {"User-Agent": "Mozilla/5.0"} # Daha standart bir User-Agent
html = requests.get(url, headers=headers).text

# Tüm tabloları bir listeye al
tables = pd.read_html(html)

# Kaç tablo bulunduğuna bak
print(f"Toplam tablo sayısı: {len(tables)}")

# Genellikle GDP tablosu büyük olandır, ilk birkaç tabloyu kontrol et
df = tables[2] 
print(df.head())
# Out:
# Toplam tablo sayısı: 8
#   Country/Territory IMF (2026)[1] World Bank (2024)[6]  \
# 0             World     126295331            111326370
# 1     United States      32383920             28750956
# 2        China[n 1]      20851593             18743803
# 3           Germany       5452858              4685593
# 4             Japan       4379253              4027598
#
#   United Nations (2024)[7]
# 0                100834796
# 1                 29298000
# 2                 18743802
# 3                  4659929
# 4                  4026211
# /var/folders/jz/r6ptw_ts6h9gb32_v0twwpm80000gn/T/ipykernel_20599/503573375.py:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)

# %%
pip install gtts
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Robotlari Konusturma

cuml = 'Hello class. welcome to our data science bootcamp'
cuml2 = 'Merhaba arkadaslar, Yapay zeka dersinize hosgeldiniz'
from gtts import gTTS

kayit = gTTS(text = cuml2, lang = "tr", slow = False)
kayit.save('robot.mp3')

# %%
from IPython.display import Audio

audio = Audio('robot.mp3')
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
